# %%
import pandas as pd
data1={
    "name":["saly","mary","john"],
    "age":[50,40,30]
}
data2={
    "qualified":[True,False,False]
}
df1=pd.DataFrame(data1)
print("Original DataFrame1:\n",df1)
df2=pd.DataFrame(data2)
print("\nOriginal DataFrame 2:\n",df2)
newdf=df1.join(df2)
print("\njoining the above two DataFrames rising join operation:\n",newdf)
df1=pd.DataFrame([[1,2],[3,4]])
df2=pd.DataFrame([[5,6],[7,8]])
def myfunc(a,b):
    if(a.sum()>b.sum()):
        return a
    else:
        return b
print("\noriginal DataFrame 1:\n",df1)
print("\noritinal dataFrame 2:\n",df2)
# Out:
# Original DataFrame1:
#     name  age
# 0  saly   50
# 1  mary   40
# 2  john   30
#
# Original DataFrame 2:
#     qualified
# 0       True
# 1      False
# 2      False
#
# joining the above two DataFrames rising join operation:
#     name  age  qualified
# 0  saly   50       True
# 1  mary   40      False
# 2  john   30      False
#
# original DataFrame 1:
#     0  1
# 0  1  2
# 1  3  4
#
# oritinal dataFrame 2:
#     0  1
# 0  5  6
# 1  7  8
#
# combining the above two DataFrames using combine function with some condition:
#     0  1
# 0  5  6
# 1  7  8
#
# original DataFrame 1:
#      name  age
# 0  sally   50
# 1   mary   40
# 2   john   30
#
# original DataFrame 2:
#      name  age
# 0  sally   77
# 1  peter   44
# 2  micky   22
#
# merge operation:
#      name  age
# 0  sally   77
# 1  peter   44
# 2  micky   22
#
# original DataFrame:
#    team  points  assists  rebounds
# 0    A      88       12        22
# 1    B      91       17        28
# 2    C      99       24        30
# 3    D      94       28        31
#
# Reshaped DataFreme:
#     team  variable  value
# 0     A    points     88
# 1     B    points     91
# 2     C    points     99
# 3     D    points     94
# 4     A   assists     12
# 5     B   assists     17
# 6     C   assists     24
# 7     D   assists     28
# 8     A  rebounds     22
# 9     B  rebounds     28
# 10    C  rebounds     30
# 11    D  rebounds     31
